# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision import models, datasets
from torchvision.models import VGG19_Weights
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## Step 1: Load and Preprocess Data
# Define transformations for images
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize images for pre-trained model input
    transforms.ToTensor(),
    #transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # Standard normalization for pre-trained models
])

# %%
# !unzip -qq "/content/drive/MyDrive/deep learning csv files/chip_data.zip" -d data

# %%
# Load dataset from a folder (structured as: dataset/class_name/images)
dataset_path = "./data/dataset/"
train_dataset = datasets.ImageFolder(root=f"{dataset_path}/train", transform=transform)
test_dataset = datasets.ImageFolder(root=f"{dataset_path}/test", transform=transform)

# %%
# Display some input images
def show_sample_images(dataset, num_images=5):
    fig, axes = plt.subplots(1, num_images, figsize=(5, 5))
    for i in range(num_images):
        image, label = dataset[i]
        image = image.permute(1, 2, 0)  # Convert tensor format (C, H, W) to (H, W, C)
        axes[i].imshow(image)
        axes[i].set_title(dataset.classes[label])
        axes[i].axis("off")
    plt.show()

# %%
# Show sample images from the training dataset
show_sample_images(train_dataset)

# %%
# Get the total number of samples in the training dataset
print(f"Total number of training samples: {len(train_dataset)}")

# Get the shape of the first image in the dataset
first_image, label = train_dataset[0]
print(f"Shape of the first image: {first_image.shape}")
# Out:
# Total number of training samples: 172
# Shape of the first image: torch.Size([3, 224, 224])

# %%
# Get the total number of samples in the testing dataset
print(f"Total number of testing samples: {len(test_dataset)}")

# Get the shape of the first image in the dataset
first_image1, label = test_dataset[0]
print(f"Shape of the first image: {first_image1.shape}")
# Out:
# Total number of testing samples: 121
# Shape of the first image: torch.Size([3, 224, 224])

# %%
# Create DataLoader for batch processing
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
## Step 2: Load Pretrained Model and Modify for Transfer Learning
# Load a pre-trained VGG19 model
# write your code here
model = models.vgg19(weights=VGG19_Weights.DEFAULT)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:07<00:00, 74.9MB/s]

# %%
# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
from torchsummary import summary
# Print model summary
summary(model, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#            Conv2d-17          [-1, 256, 56, 56]         590,080
#              ReLU-18          [-1, 256, 56, 56]               0
#         MaxPool2d-19          [-1, 256, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       1,180,160
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#            Conv2d-24          [-1, 512, 28, 28]       2,359,808
#              ReLU-25          [-1, 512, 28, 28]               0
#            Conv2d-26          [-1, 512, 28, 28]       2,359,808
#              ReLU-27          [-1, 512, 28, 28]               0
#         MaxPool2d-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#            Conv2d-31          [-1, 512, 14, 14]       2,359,808
#              ReLU-32          [-1, 512, 14, 14]               0
#            Conv2d-33          [-1, 512, 14, 14]       2,359,808
#              ReLU-34          [-1, 512, 14, 14]               0
#            Conv2d-35          [-1, 512, 14, 14]       2,359,808
#              ReLU-36          [-1, 512, 14, 14]               0
#         MaxPool2d-37            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-38            [-1, 512, 7, 7]               0
#            Linear-39                 [-1, 4096]     102,764,544
#              ReLU-40                 [-1, 4096]               0
#           Dropout-41                 [-1, 4096]               0
#            Linear-42                 [-1, 4096]      16,781,312
#              ReLU-43                 [-1, 4096]               0
#           Dropout-44                 [-1, 4096]               0
#            Linear-45                 [-1, 1000]       4,097,000
# ================================================================
# Total params: 143,667,240
# Trainable params: 143,667,240
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 238.69
# Params size (MB): 548.05
# Estimated Total Size (MB): 787.31
# ----------------------------------------------------------------

# %%
# Modify the final fully connected layer to match the dataset classes
# Write your code here
model.classifier[-1]=nn.Linear(model.classifier[-1].in_features,1)

# %%
# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
summary(model, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#            Conv2d-17          [-1, 256, 56, 56]         590,080
#              ReLU-18          [-1, 256, 56, 56]               0
#         MaxPool2d-19          [-1, 256, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       1,180,160
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#            Conv2d-24          [-1, 512, 28, 28]       2,359,808
#              ReLU-25          [-1, 512, 28, 28]               0
#            Conv2d-26          [-1, 512, 28, 28]       2,359,808
#              ReLU-27          [-1, 512, 28, 28]               0
#         MaxPool2d-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#            Conv2d-31          [-1, 512, 14, 14]       2,359,808
#              ReLU-32          [-1, 512, 14, 14]               0
#            Conv2d-33          [-1, 512, 14, 14]       2,359,808
#              ReLU-34          [-1, 512, 14, 14]               0
#            Conv2d-35          [-1, 512, 14, 14]       2,359,808
#              ReLU-36          [-1, 512, 14, 14]               0
#         MaxPool2d-37            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-38            [-1, 512, 7, 7]               0
#            Linear-39                 [-1, 4096]     102,764,544
#              ReLU-40                 [-1, 4096]               0
#           Dropout-41                 [-1, 4096]               0
#            Linear-42                 [-1, 4096]      16,781,312
#              ReLU-43                 [-1, 4096]               0
#           Dropout-44                 [-1, 4096]               0
#            Linear-45                    [-1, 1]           4,097
# ================================================================
# Total params: 139,574,337
# Trainable params: 139,574,337
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 238.68
# Params size (MB): 532.43
# Estimated Total Size (MB): 771.69
# ----------------------------------------------------------------

# %%
# Freeze all layers except the final layer
for param in model.features.parameters():
    param.requires_grad = False  # Freeze feature extractor layers

# %%
# Include the Loss function and optimizer
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(),lr=0.001)

# %%
# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
# Train the model
# Write your code here
train_model(model, train_loader,test_loader)
# Out:
# Epoch [1/100], Train Loss: 0.8408, Validation Loss: 0.2336
# Epoch [2/100], Train Loss: 0.1604, Validation Loss: 0.2000
# Epoch [3/100], Train Loss: 0.0242, Validation Loss: 0.0585
# Epoch [4/100], Train Loss: 0.0014, Validation Loss: 0.0736
# Epoch [5/100], Train Loss: 0.0008, Validation Loss: 0.1490
# Epoch [6/100], Train Loss: 0.0000, Validation Loss: 0.1722
# Epoch [7/100], Train Loss: 0.0000, Validation Loss: 0.1298
# Epoch [8/100], Train Loss: 0.0284, Validation Loss: 0.1289
# Epoch [9/100], Train Loss: 0.0015, Validation Loss: 0.1634
# Epoch [10/100], Train Loss: 0.0135, Validation Loss: 0.5106
# Epoch [11/100], Train Loss: 0.0049, Validation Loss: 0.2818
# Epoch [12/100], Train Loss: 0.3780, Validation Loss: 0.4659
# Epoch [13/100], Train Loss: 0.4249, Validation Loss: 3.4478
# Epoch [14/100], Train Loss: 0.3450, Validation Loss: 0.6415
# Epoch [15/100], Train Loss: 0.2302, Validation Loss: 1.0927
# Epoch [16/100], Train Loss: 0.0777, Validation Loss: 0.7736
# Epoch [17/100], Train Loss: 0.0010, Validation Loss: 0.4847
# Epoch [18/100], Train Loss: 0.0000, Validation Loss: 0.3210
# Epoch [19/100], Train Loss: 0.1499, Validation Loss: 2.3571
# Epoch [20/100], Train Loss: 0.0000, Validation Loss: 2.9551
# Epoch [21/100], Train Loss: 0.3537, Validation Loss: 1.6080
# Epoch [22/100], Train Loss: 0.1043, Validation Loss: 4.3256
# Epoch [23/100], Train Loss: 0.1136, Validation Loss: 1.8272
# Epoch [24/100], Train Loss: 0.0226, Validation Loss: 3.0002
# Epoch [25/100], Train Loss: 0.0010, Validation Loss: 3.5575
# Epoch [26/100], Train Loss: 0.0835, Validation Loss: 1.5937
# Epoch [27/100], Train Loss: 0.1432, Validation Loss: 8.0178
# Epoch [28/100], Train Loss: 0.8320, Validation Loss: 6.5790
# Epoch [29/100], Train Loss: 0.0000, Validation Loss: 1.2687
# Epoch [30/100], Train Loss: 0.0845, Validation Loss: 1.8913
# Epoch [31/100], Train Loss: 0.2148, Validation Loss: 8.5527
# Epoch [32/100], Train Loss: 0.2492, Validation Loss: 2.5110
# Epoch [33/100], Train Loss: 0.7913, Validation Loss: 4.0373
# Epoch [34/100], Train Loss: 0.2835, Validation Loss: 2.0656
# Epoch [35/100], Train Loss: 0.0000, Validation Loss: 2.7642
# Epoch [36/100], Train Loss: 0.0000, Validation Loss: 3.4886
# Epoch [37/100], Train Loss: 0.0000, Validation Loss: 3.9728
# Epoch [38/100], Train Loss: 0.0000, Validation Loss: 4.2366
# Epoch [39/100], Train Loss: 0.0318, Validation Loss: 2.3132
# Epoch [40/100], Train Loss: 0.4039, Validation Loss: 2.6982
# Epoch [41/100], Train Loss: 0.0926, Validation Loss: 2.3011
# Epoch [42/100], Train Loss: 0.0000, Validation Loss: 0.7413
# Epoch [43/100], Train Loss: 0.0000, Validation Loss: 0.6120
# Epoch [44/100], Train Loss: 0.0003, Validation Loss: 0.5670
# Epoch [45/100], Train Loss: 0.1173, Validation Loss: 8.0899
# Epoch [46/100], Train Loss: 0.1394, Validation Loss: 1.0584
# Epoch [47/100], Train Loss: 0.0000, Validation Loss: 4.2577
# Epoch [48/100], Train Loss: 0.2686, Validation Loss: 3.3155
# Epoch [49/100], Train Loss: 0.2381, Validation Loss: 1.4776
# Epoch [50/100], Train Loss: 0.4307, Validation Loss: 2.6685
# Epoch [51/100], Train Loss: 0.0000, Validation Loss: 4.5256
# Epoch [52/100], Train Loss: 0.0000, Validation Loss: 6.3535
# Epoch [53/100], Train Loss: 0.0000, Validation Loss: 7.7081
# Epoch [54/100], Train Loss: 0.0587, Validation Loss: 2.9961
# Epoch [55/100], Train Loss: 0.0000, Validation Loss: 3.6255
# Epoch [56/100], Train Loss: 0.3241, Validation Loss: 3.8465
# Epoch [57/100], Train Loss: 0.0000, Validation Loss: 9.9380
# Epoch [58/100], Train Loss: 0.2004, Validation Loss: 3.1155
# Epoch [59/100], Train Loss: 1.7801, Validation Loss: 2.1720
# Epoch [60/100], Train Loss: 0.0000, Validation Loss: 16.0764
# Epoch [61/100], Train Loss: 2.0743, Validation Loss: 2.9752
# Epoch [62/100], Train Loss: 1.9519, Validation Loss: 2.2922
# Epoch [63/100], Train Loss: 0.0000, Validation Loss: 20.7561
# Epoch [64/100], Train Loss: 1.6203, Validation Loss: 2.6543
# Epoch [65/100], Train Loss: 0.0000, Validation Loss: 4.8681
# Epoch [66/100], Train Loss: 0.1661, Validation Loss: 4.3780
# Epoch [67/100], Train Loss: 0.0000, Validation Loss: 4.3614
# Epoch [68/100], Train Loss: 0.0959, Validation Loss: 2.8692
# Epoch [69/100], Train Loss: 0.0000, Validation Loss: 2.8686
# Epoch [70/100], Train Loss: 0.9773, Validation Loss: 2.6916
# Epoch [71/100], Train Loss: 0.0000, Validation Loss: 2.9376
# Epoch [72/100], Train Loss: 0.6363, Validation Loss: 1.7189
# Epoch [73/100], Train Loss: 0.0000, Validation Loss: 4.9700
# Epoch [74/100], Train Loss: 0.0000, Validation Loss: 15.8519
# Epoch [75/100], Train Loss: 0.3172, Validation Loss: 11.2262
# Epoch [76/100], Train Loss: 0.0000, Validation Loss: 4.7208
# Epoch [77/100], Train Loss: 0.0000, Validation Loss: 3.1851
# Epoch [78/100], Train Loss: 0.0000, Validation Loss: 2.8560
# Epoch [79/100], Train Loss: 0.0000, Validation Loss: 2.7765
# Epoch [80/100], Train Loss: 0.0000, Validation Loss: 2.7337
# Epoch [81/100], Train Loss: 0.0000, Validation Loss: 2.7306
# Epoch [82/100], Train Loss: 0.0000, Validation Loss: 2.7400
# Epoch [83/100], Train Loss: 0.0000, Validation Loss: 2.7452
# Epoch [84/100], Train Loss: 0.0000, Validation Loss: 2.7480
# Epoch [85/100], Train Loss: 0.0000, Validation Loss: 2.7495
# Epoch [86/100], Train Loss: 0.0000, Validation Loss: 2.7503
# Epoch [87/100], Train Loss: 0.0000, Validation Loss: 2.7508
# Epoch [88/100], Train Loss: 0.0000, Validation Loss: 2.7510
# Epoch [89/100], Train Loss: 0.0000, Validation Loss: 2.7511
# Epoch [90/100], Train Loss: 0.0000, Validation Loss: 2.7512
# Epoch [91/100], Train Loss: 0.0000, Validation Loss: 2.7512
# Epoch [92/100], Train Loss: 0.0000, Validation Loss: 2.7512
# Epoch [93/100], Train Loss: 0.0000, Validation Loss: 2.7513
# Epoch [94/100], Train Loss: 0.0000, Validation Loss: 2.7513
# Epoch [95/100], Train Loss: 0.0000, Validation Loss: 2.7513
# Epoch [96/100], Train Loss: 0.0000, Validation Loss: 2.7513
# Epoch [97/100], Train Loss: 0.0000, Validation Loss: 2.7513
# Epoch [98/100], Train Loss: 0.0000, Validation Loss: 2.7513
# Epoch [99/100], Train Loss: 0.0000, Validation Loss: 2.7513
# Epoch [100/100], Train Loss: 0.0000, Validation Loss: 2.7513
# Name: SANJAY V
# Register Number: 212223230188

# %%
## Step 4: Test the Model and Compute Confusion Matrix & Classification Report
def test_model(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.float().unsqueeze(1).to(device)
            outputs = model(images)
            probs = torch.sigmoid(outputs)
            predicted = (probs > 0.5).int()
            total += labels.size(0)
            correct += (predicted == labels.int()).sum().item()
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy().astype(int))

    accuracy = correct / total
    print(f'Test Accuracy: {accuracy:.4f}')

    # Compute confusion matrix
    cm = confusion_matrix(all_labels, all_preds)
    print("Name: SANJAY V")
    print("Register Number: 212223230188       ")
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=train_dataset.classes, yticklabels=train_dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

    # Print classification report
    print("Name: SANJAY V")
    print("Register Number: 212223230188")
    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=train_dataset.classes))

# %%
# Evaluate the model
# write your code here
test_model(model, test_loader)
# Out:
# Test Accuracy: 0.9752
# Name: SANJAY V
# Register Number: 212223230188
# Name: SANJAY V
# Register Number: 212223230188
# Classification Report:
#               precision    recall  f1-score   support
#
#       defect       0.94      0.97      0.96        33
#    notdefect       0.99      0.98      0.98        88
#
#     accuracy                           0.98       121
#    macro avg       0.96      0.97      0.97       121
# weighted avg       0.98      0.98      0.98       121

# %%
## Step 5: Predict on a Single Image and Display It
def predict_image(model, image_index, dataset):
    model.eval()
    image, label = dataset[image_index]
    with torch.no_grad():
        image_tensor = image.unsqueeze(0).to(device)
        output = model(image_tensor)

        # Apply sigmoid to get probability, threshold at 0.5
        prob = torch.sigmoid(output)
        predicted = (prob > 0.5).int().item()


    class_names = class_names = dataset.classes
    # Display the image
    image_to_display = transforms.ToPILImage()(image)
    plt.figure(figsize=(4, 4))
    plt.imshow(image_to_display)
    plt.title(f'Actual: {class_names[label]}\nPredicted: {class_names[predicted]}')
    plt.axis("off")
    plt.show()

    print(f'Actual: {class_names[label]}, Predicted: {class_names[predicted]}')

# %%
# Example Prediction
predict_image(model, image_index=55, dataset=test_dataset)
# Out:
# Actual: notdefect, Predicted: notdefect

# %%
#Example Prediction
predict_image(model, image_index=25, dataset=test_dataset)
# Out:
# Actual: defect, Predicted: defect
